# %%
from dataset_module import load_stroke_clinical_dataset_record
from ui_module import run_ui

# %%
# Load data from file
print("***********--------- Stroke Statistical Analysis Applicationn---------************")
data_file = "data.csv"
print("Loading dataset...")
data = load_stroke_clinical_dataset_record(data_file)
print("Dataset loaded successfully with", len(data), "records.")
# Out:
# ***********--------- Stroke Statistical Analysis Applicationn---------************
# Loading dataset...
# Dataset loaded successfully with 172000 records.

# %%
# Launch the user interface
run_ui(data)
# Out:
# ***********************Stroke Data Analytics Menu***********************
# 1. Average/Median/Modal age of smokers with hypertension and stroke
# 2. Average/Median/Modal age & glucose level of patients with heart disease and stroke
# 3. Age analysis based on gender and hypertension (stroke vs no stroke)
# 4. Smoking habit vs stroke age analysis
# 5. Urban vs Rural stroke age analysis
# 6. Dietary habits of stroke vs non-stroke patients
# 7. Patients with hypertension that led to stroke
# 8. Patients by hypertension-stroke status
# 9. Heart disease with stroke
# 10. Descriptive stats of any feature
# 11. Average sleep hours (stroke vs non-stroke)
# 0. Exit
# ----------------------------------
# Enter the option you wish to analyze:  5
# Results saved successfully to area_lived_stroke.csv
#  Do you want to continue? (Yes or No):  no
# Thanks for using the system
